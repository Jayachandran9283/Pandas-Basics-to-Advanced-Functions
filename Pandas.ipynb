# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\jayac\Downloads\Data science\IMDB-Movie-Data.csv",index_col='Title')

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.head(30)
# Out:
#                                          Rank                       Genre  \
# Title
# Guardians of the Galaxy                     1     Action,Adventure,Sci-Fi
# Prometheus                                  2    Adventure,Mystery,Sci-Fi
# Split                                       3             Horror,Thriller
# Sing                                        4     Animation,Comedy,Family
# Suicide Squad                               5    Action,Adventure,Fantasy
# The Great Wall                              6    Action,Adventure,Fantasy
# La La Land                                  7          Comedy,Drama,Music
# Mindhorn                                    8                      Comedy
# The Lost City of Z                          9  Action,Adventure,Biography
# Passengers                                 10     Adventure,Drama,Romance
# Fantastic Beasts and Where to Find Them    11    Adventure,Family,Fantasy
# Hidden Figures                             12     Biography,Drama,History
# ...

# %%
df.tail(15)
# Out:
#                                 Rank                     Genre  \
# Title
# Your Highness                    986  Adventure,Comedy,Fantasy
# Final Destination 5              987           Horror,Thriller
# Endless Love                     988             Drama,Romance
# Martyrs                          989                    Horror
# Selma                            990   Biography,Drama,History
# Underworld: Rise of the Lycans   991  Action,Adventure,Fantasy
# Taare Zameen Par                 992        Drama,Family,Music
# Take Me Home Tonight             993      Comedy,Drama,Romance
# Resident Evil: Afterlife         994   Action,Adventure,Horror
# Project X                        995                    Comedy
# Secret in Their Eyes             996       Crime,Drama,Mystery
# Hostel: Part II                  997                    Horror
# Step Up 2: The Streets           998       Drama,Music,Romance
# Search Party                     999          Adventure,Comedy
# ...

# %%
name=df.columns.values
name
# Out:
# array(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
df.loc[df['Rank'] > 500]
# Out:
# Rank                  500
# Genre                 500
# Description           500
# Director              500
# Actors                500
# Year                  500
# Runtime (Minutes)     500
# Rating                500
# Votes                 500
# Revenue (Millions)    424
# Metascore             464
# dtype: int64

# %%
df[df['Rank'] > 500]
# Out:
#                                 Rank                   Genre  \
# Title
# Maze Runner: The Scorch Trials   501  Action,Sci-Fi,Thriller
# Carol                            502           Drama,Romance
# Imperium                         503    Crime,Drama,Thriller
# Youth                            504      Comedy,Drama,Music
# Mr. Nobody                       505   Drama,Fantasy,Romance
# ...                              ...                     ...
# Secret in Their Eyes             996     Crime,Drama,Mystery
# Hostel: Part II                  997                  Horror
# Step Up 2: The Streets           998     Drama,Music,Romance
# Search Party                     999        Adventure,Comedy
# Nine Lives                      1000   Comedy,Family,Fantasy
#
#                                                                       Description  \
# Title
# Maze Runner: The Scorch Trials  After having escaped the Maze, the Gladers now...
# ...

# %%
df.columns.str.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-99bf64c02843> in <module>
# ----> 1 df.columns.lower()
#
# AttributeError: 'Index' object has no attribute 'lower'

# %%
df=df.rename(columns=str.lower)

# %%
newdf=df.loc[:,['genre','rank','director']]

# %%
df[['rank']]
df.head()
# Out:
#                          rank                     genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
df[['runtime (minutes)']]>80 & df[['year']]==2016
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-8d9cbd9adf12> in <module>
# ----> 1 df[['runtime (minutes)']]>80 & df[['year']]==2016
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other)
#     836             # Another DataFrame
#     837             if not self._indexed_same(other):
# --> 838                 raise ValueError(
#     839                     "Can only compare identically-labeled DataFrame objects"
#     840                 )
#
# ValueError: Can only compare identically-labeled DataFrame objects

# %%
df.dropna(inplace=True)

# %%
df.loc[(df['runtime (minutes)'] > 80) & (df['year']==2016)]
# Out:
#                             rank                     genre  \
# Title
# Split                          3           Horror,Thriller
# Sing                           4   Animation,Comedy,Family
# Suicide Squad                  5  Action,Adventure,Fantasy
# The Great Wall                 6  Action,Adventure,Fantasy
# La La Land                     7        Comedy,Drama,Music
# ...                          ...                       ...
# King Cobra                   948               Crime,Drama
# Queen of Katwe               975     Biography,Drama,Sport
# My Big Fat Greek Wedding 2   976     Comedy,Family,Romance
# Miracles from Heaven         981    Biography,Drama,Family
# Nine Lives                  1000     Comedy,Family,Fantasy
#
#                                                                   description  \
# Title
# Split                       Three girls are kidnapped by a man with a diag...
# Sing                        In a city of humanoid animals, a hustling thea...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-baed29e87872> in <module>
# ----> 1 for i ,j in df.iterrows:
#       2     print(i,j)
#
# TypeError: 'method' object is not iterable
