# %%
import pandas as pd

# %%
df = pd.read_csv("orders.csv")

# %%
df.head(2)
# Out:
#            Order Id        Date           Meal Id        Company Id  \
# 0  839FKFW2LLX4LMBB  2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1  97OX39BGVMHODLJM  2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
#
#                 Date of Meal      Participants  Meal Price Type of Meal  \
# 0  2016-05-31 07:00:00+02:00  ['David Bishop']       469.0    Breakfast
# 1  2018-10-01 20:00:00+02:00  ['David Bishop']        22.0       Dinner
#
#   Heroes Adjustment
# 0             False
# 1             False

# %%
df.sample(2)
# Out:
#                Order Id        Date           Meal Id        Company Id  \
# 1942   HI35JTHVI8U9H5W9  2015-10-31  20AZVSFQ7HKSFAD2  SFHNR0WDFYEA8FIL
# 10136  XE1JCSLX7CAW4E5F  2016-05-04  ZFU5UBWBT9031N1O  M05B6B49B0YB0U5S
#
#                     Date of Meal           Participants  Meal Price  \
# 1942   2015-10-29 21:00:00+01:00  ['Josefina Schuyler']       676.0
# 10136  2016-05-06 08:00:00+02:00      ['Thomas Norman']       846.0
#
#       Type of Meal Heroes Adjustment
# 1942        Dinner             False
# 10136    Breakfast             False

# %%
df.dtypes
# Out:
# Order Id              object
# Date                  object
# Meal Id               object
# Company Id            object
# Date of Meal          object
# Participants          object
# Meal Price           float64
# Type of Meal          object
# Heroes Adjustment     object
# dtype: object

# %%
df['Type of Meal'].value_counts()
# Out:
# Dinner       4848
# Breakfast    4766
# Lunch        4747
# Name: Type of Meal, dtype: int64

# %%
df['Date'] = df['Date'].astype('datetime64')

# %%
df.dtypes
# Out:
# Order Id                     object
# Date                 datetime64[ns]
# Meal Id                      object
# Company Id                   object
# Date of Meal                 object
# Participants                 object
# Meal Price                  float64
# Type of Meal                 object
# Heroes Adjustment            object
# dtype: object

# %%
df['Date'].dt.date
# Out:
# 0        2016-05-27
# 1        2018-09-27
# 2        2014-08-24
# 3        2014-04-12
# 4        2015-07-28
# 5        2014-07-21
# 6        2014-04-29
# 7        2014-05-08
# 8        2015-05-23
# 9        2016-01-10
# 10       2016-10-03
# 11       2018-07-23
# 12       2016-12-15
# 13       2017-09-17
# 14       2016-08-31
# 15       2018-12-25
# 16       2017-05-25
# 17       2018-06-20
# 18       2017-10-22
# 19       2017-01-27
# 20       2014-08-24
# 21       2017-07-09
# 22       2017-03-25
# 23       2015-01-05
# 24       2014-08-05
# 25       2016-06-10
# 26       2016-09-25
# 27       2014-01-30
# 28       2018-01-21
# 29       2014-09-28
#             ...
# 14332    2014-02-09
# 14333    2018-02-14
# 14334    2017-08-31
# 14335    2015-03-21
# 14336    2017-10-14
# 14337    2017-10-25
# 14338    2014-02-21
# 14339    2016-11-21
# 14340    2015-04-08
# 14341    2015-07-06
# 14342    2014-08-01
# 14343    2014-03-11
# 14344    2014-02-27
# 14345    2014-07-11
# ...

# %%
df['Date'].dt.month_name()
# Out:
# 0              May
# 1        September
# 2           August
# 3            April
# 4             July
# 5             July
# 6            April
# 7              May
# 8              May
# 9          January
# 10         October
# 11            July
# 12        December
# 13       September
# 14          August
# 15        December
# 16             May
# 17            June
# 18         October
# 19         January
# 20          August
# 21            July
# 22           March
# 23         January
# 24          August
# 25            June
# 26       September
# 27         January
# 28         January
# 29       September
#            ...
# 14332     February
# 14333     February
# 14334       August
# 14335        March
# 14336      October
# 14337      October
# 14338     February
# 14339     November
# 14340        April
# 14341         July
# 14342       August
# 14343        March
# 14344     February
# 14345         July
# 14346      October
# 14347        April
# ...

# %%
df['Date'].dt.weekday_name
# Out:
# 0           Friday
# 1         Thursday
# 2           Sunday
# 3         Saturday
# 4          Tuesday
# 5           Monday
# 6          Tuesday
# 7         Thursday
# 8         Saturday
# 9           Sunday
# 10          Monday
# 11          Monday
# 12        Thursday
# 13          Sunday
# 14       Wednesday
# 15         Tuesday
# 16        Thursday
# 17       Wednesday
# 18          Sunday
# 19          Friday
# 20          Sunday
# 21          Sunday
# 22        Saturday
# 23          Monday
# 24         Tuesday
# 25          Friday
# 26          Sunday
# 27        Thursday
# 28          Sunday
# 29          Sunday
#            ...
# 14332       Sunday
# 14333    Wednesday
# 14334     Thursday
# 14335     Saturday
# 14336     Saturday
# 14337    Wednesday
# 14338       Friday
# 14339       Monday
# 14340    Wednesday
# 14341       Monday
# 14342       Friday
# 14343      Tuesday
# 14344     Thursday
# 14345       Friday
# 14346    Wednesday
# 14347       Sunday
# ...

# %%
df['Date'].dt.quarter
# Out:
# 0        2
# 1        3
# 2        3
# 3        2
# 4        3
# 5        3
# 6        2
# 7        2
# 8        2
# 9        1
# 10       4
# 11       3
# 12       4
# 13       3
# 14       3
# 15       4
# 16       2
# 17       2
# 18       4
# 19       1
# 20       3
# 21       3
# 22       1
# 23       1
# 24       3
# 25       2
# 26       3
# 27       1
# 28       1
# 29       3
#         ..
# 14332    1
# 14333    1
# 14334    3
# 14335    1
# 14336    4
# 14337    4
# 14338    1
# 14339    4
# 14340    2
# 14341    3
# 14342    3
# 14343    1
# 14344    1
# 14345    3
# 14346    4
# 14347    2
# 14348    3
# 14349    4
# 14350    2
# 14351    1
# 14352    1
# 14353    2
# 14354    4
# 14355    3
# 14356    3
# 14357    1
# 14358    2
# 14359    2
# 14360    3
# 14361    1
# Name: Date, Length: 14362, dtype: int64

# %%
df['Date'].dt.year
# Out:
# 0        2016
# 1        2018
# 2        2014
# 3        2014
# 4        2015
# 5        2014
# 6        2014
# 7        2014
# 8        2015
# 9        2016
# 10       2016
# 11       2018
# 12       2016
# 13       2017
# 14       2016
# 15       2018
# 16       2017
# 17       2018
# 18       2017
# 19       2017
# 20       2014
# 21       2017
# 22       2017
# 23       2015
# 24       2014
# 25       2016
# 26       2016
# 27       2014
# 28       2018
# 29       2014
#          ...
# 14332    2014
# 14333    2018
# 14334    2017
# 14335    2015
# 14336    2017
# 14337    2017
# 14338    2014
# 14339    2016
# 14340    2015
# 14341    2015
# 14342    2014
# 14343    2014
# 14344    2014
# 14345    2014
# 14346    2018
# 14347    2016
# 14348    2018
# 14349    2018
# 14350    2016
# 14351    2015
# 14352    2016
# 14353    2016
# 14354    2015
# 14355    2016
# 14356    2017
# 14357    2018
# 14358    2016
# 14359    2016
# 14360    2015
# 14361    2017
# ...

# %%
## Categories

# %%
df['Type of Meal'] = df['Type of Meal'].astype('category')

# %%
df['Type of Meal'].cat.categories
# Out:
# Index(['Breakfast', 'Dinner', 'Lunch'], dtype='object')

# %%
df['Type of Meal']
# Out:
# 0        Breakfast
# 1           Dinner
# 2            Lunch
# 3           Dinner
# 4            Lunch
# 5           Dinner
# 6           Dinner
# 7        Breakfast
# 8            Lunch
# 9           Dinner
# 10          Dinner
# 11       Breakfast
# 12       Breakfast
# 13           Lunch
# 14           Lunch
# 15           Lunch
# 16          Dinner
# 17       Breakfast
# 18           Lunch
# 19           Lunch
# 20           Lunch
# 21       Breakfast
# 22       Breakfast
# 23          Dinner
# 24           Lunch
# 25       Breakfast
# 26       Breakfast
# 27       Breakfast
# 28           Lunch
# 29          Dinner
#            ...
# 14332       Dinner
# 14333       Dinner
# 14334    Breakfast
# 14335       Dinner
# 14336       Dinner
# 14337       Dinner
# 14338       Dinner
# 14339    Breakfast
# 14340        Lunch
# 14341       Dinner
# 14342       Dinner
# 14343       Dinner
# 14344    Breakfast
# 14345    Breakfast
# 14346    Breakfast
# 14347    Breakfast
# ...

# %%
df['Type of Meal'].cat.codes
# Out:
# 0        0
# 1        1
# 2        2
# 3        1
# 4        2
# 5        1
# 6        1
# 7        0
# 8        2
# 9        1
# 10       1
# 11       0
# 12       0
# 13       2
# 14       2
# 15       2
# 16       1
# 17       0
# 18       2
# 19       2
# 20       2
# 21       0
# 22       0
# 23       1
# 24       2
# 25       0
# 26       0
# 27       0
# 28       2
# 29       1
#         ..
# 14332    1
# 14333    1
# 14334    0
# 14335    1
# 14336    1
# 14337    1
# 14338    1
# 14339    0
# 14340    2
# 14341    1
# 14342    1
# 14343    1
# 14344    0
# 14345    0
# 14346    0
# 14347    0
# 14348    1
# 14349    1
# 14350    1
# 14351    1
# 14352    0
# 14353    2
# 14354    0
# 14355    2
# 14356    0
# 14357    2
# 14358    1
# 14359    0
# 14360    0
# 14361   -1
# Length: 14362, dtype: int8

# %%
df['Type of Meal'].cat.reorder_categories(['Lunch','Dinner','Breakfast'])
# Out:
# 0        Breakfast
# 1           Dinner
# 2            Lunch
# 3           Dinner
# 4            Lunch
# 5           Dinner
# 6           Dinner
# 7        Breakfast
# 8            Lunch
# 9           Dinner
# 10          Dinner
# 11       Breakfast
# 12       Breakfast
# 13           Lunch
# 14           Lunch
# 15           Lunch
# 16          Dinner
# 17       Breakfast
# 18           Lunch
# 19           Lunch
# 20           Lunch
# 21       Breakfast
# 22       Breakfast
# 23          Dinner
# 24           Lunch
# 25       Breakfast
# 26       Breakfast
# 27       Breakfast
# 28           Lunch
# 29          Dinner
#            ...
# 14332       Dinner
# 14333       Dinner
# 14334    Breakfast
# 14335       Dinner
# 14336       Dinner
# 14337       Dinner
# 14338       Dinner
# 14339    Breakfast
# 14340        Lunch
# 14341       Dinner
# 14342       Dinner
# 14343       Dinner
# 14344    Breakfast
# 14345    Breakfast
# 14346    Breakfast
# 14347    Breakfast
# ...

# %%
df['Meal Price'] = df['Meal Price'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-399d2d033a66> in <module>()
# ----> 1 df['Meal Price'] = df['Meal Price'].astype('int')
#
# c:\users\aadhi\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# c:\users\aadhi\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ...

# %%
df.isna().sum()
# Out:
# Order Id             0
# Date                 0
# Meal Id              0
# Company Id           0
# Date of Meal         1
# Participants         1
# Meal Price           1
# Type of Meal         1
# Heroes Adjustment    1
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (14361, 9)

# %%
#Assignment
Insert a value at index 70000 and to the specified column
1. 70000
2. col = "Meal Price"
Value = "Not a number but a string"

# %%
Apply! 
df.apply()
'''
Signature: df.apply(func, axis=0, broadcast=None, raw=False, reduce=None, result_type=None, args=(), **kwds)
Docstring:
Apply a function along an axis of the DataFrame.

Objects passed to the function are Series objects whose index is
either the DataFrame's index (``axis=0``) or the DataFrame's columns
(``axis=1``). By default (``result_type=None``), the final return type
is inferred from the return type of the applied function. Otherwise,
it depends on the `result_type` argument.
'''
# Out:
#   File "<ipython-input-29-eda8838f69dc>", line 1
#     Apply!
#          ^
# SyntaxError: invalid syntax

# %%
df['Type of Meal'] = df['Type of Meal'].apply(lambda x: x.lower())

# %%
df['Type of Meal']
# Out:
# 0        breakfast
# 1           dinner
# 2            lunch
# 3           dinner
# 4            lunch
# 5           dinner
# 6           dinner
# 7        breakfast
# 8            lunch
# 9           dinner
# 10          dinner
# 11       breakfast
# 12       breakfast
# 13           lunch
# 14           lunch
# 15           lunch
# 16          dinner
# 17       breakfast
# 18           lunch
# 19           lunch
# 20           lunch
# 21       breakfast
# 22       breakfast
# 23          dinner
# 24           lunch
# 25       breakfast
# 26       breakfast
# 27       breakfast
# 28           lunch
# 29          dinner
#            ...
# 14331    breakfast
# 14332       dinner
# 14333       dinner
# 14334    breakfast
# 14335       dinner
# 14336       dinner
# 14337       dinner
# 14338       dinner
# 14339    breakfast
# 14340        lunch
# 14341       dinner
# 14342       dinner
# 14343       dinner
# 14344    breakfast
# 14345    breakfast
# 14346    breakfast
# ...

# %%
#Assignment 
find the value counts of different datatypes inside "Meal Price"
# Out:
#   File "<ipython-input-32-30be4f9fbd97>", line 2
#     find the value counts of different datatypes inside "Meal Price"
#            ^
# SyntaxError: invalid syntax

# %%
df.dtypes
# Out:
# Order Id                     object
# Date                 datetime64[ns]
# Meal Id                      object
# Company Id                   object
# Date of Meal                 object
# Participants                 object
# Meal Price                   object
# Type of Meal               category
# Heroes Adjustment            object
# dtype: object

# %%
df.loc[70000,'Meal Price'] = "Not a number but a string"
df['Meal Price'].apply(lambda x: type(x)).value_counts()
# Out:
# <class 'float'>    14361
# <class 'str'>          1
# Name: Meal Price, dtype: int64

# %%
name = ['THanga','Sjjjj','Sivanu','Hari','Kalyan','kll']
def l(s):
    if len(s) < 4:
        return s
list(filter(l, name))
# Out:
# ['kll']

# %%
## Adding rows or columns or Combining different DataFrames
new_row = {'Order Id':'78373RDFGT94949',
           'Date':'2020-01-03',
           'Meal Id':'EFJSOJF984929389'}

# %%
df.head()
# Out:
#            Order Id       Date           Meal Id        Company Id  \
# 0  839FKFW2LLX4LMBB 2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1  97OX39BGVMHODLJM 2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2  041ORQM5OIHTIU6L 2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3  YT796QI18WNGZ7ZJ 2014-04-12  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4  6YLROQT27B6HRF4E 2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
#
#                 Date of Meal                       Participants Meal Price  \
# 0  2016-05-31 07:00:00+02:00                   ['David Bishop']        469
# 1  2018-10-01 20:00:00+02:00                   ['David Bishop']         22
# 2  2014-08-23 14:00:00+02:00                 ['Karen Stansell']        314
# 3  2014-04-07 21:00:00+02:00                   ['Addie Patino']        438
# 4  2015-07-27 14:00:00+02:00  ['Addie Patino' 'Susan Guerrero']        690
#
#   Type of Meal Heroes Adjustment
# 0    breakfast             False
# 1       dinner             False
# ...

# %%
df_new = df.copy()

# %%
df_new = df_new.append(new_row,ignore_index = True)

# %%
df_new.tail()
# Out:
#                Order Id                 Date           Meal Id  \
# 14358  RFK2C21CD7IAOUZT  2016-06-30 00:00:00  EGQRRRN5D1Y97WGD
# 14359  2UMDU938DTE7D808  2016-04-10 00:00:00  AV323CBF7N78MCYD
# 14360  NEER4D5TN6GQV9WA  2015-07-19 00:00:00  RDLHP30JLO9RYWDR
# 14361               NaN                  NaT               NaN
# 14362   78373RDFGT94949           2020-01-03  EFJSOJF984929389
#
#              Company Id               Date of Meal  \
# 14358  I27J9NPYES4BIXBR  2016-06-26 20:00:00+02:00
# 14359  I27J9NPYES4BIXBR  2016-04-10 07:00:00+02:00
# 14360  I27J9NPYES4BIXBR  2015-07-21 09:00:00+02:00
# 14361               NaN                        NaN
# 14362               NaN                        NaN
#
#                                    Participants                 Meal Price  \
# 14358                       ['Kenisha Ordonez']                         49
# 14359                    ['Douglas Villanueva']                         81
# ...

# %%
df_new = df_new.append(df)

# %%
df_new.loc[1000,:]
# Out:
#               Order Id       Date           Meal Id        Company Id  \
# 1000  D0395E9EXLRNNC5Q 2015-05-30  8LWTFEH1ST5TCWVA  9HUDWGJ1CU1IKMEJ
# 1000  D0395E9EXLRNNC5Q 2015-05-30  8LWTFEH1ST5TCWVA  9HUDWGJ1CU1IKMEJ
#
#                    Date of Meal       Participants Meal Price Type of Meal  \
# 1000  2015-05-27 14:00:00+02:00  ['Latanya Davis']         15        lunch
# 1000  2015-05-27 14:00:00+02:00  ['Latanya Davis']         15        lunch
#
#      Heroes Adjustment
# 1000             False
# 1000             False

# %%
## Adding rows or columns or Combining different DataFrames
new_row = {'Order Id':['78373RDFGT94949','78373RDFGT94930'],
           'Date':['2020-01-03','2020-10-23'],
           'Meal Id':['EFJSOJF984929389','78373RDFGT9494fds']}

# %%
add = pd.DataFrame(new_row)

# %%
add
# Out:
#           Order Id        Date            Meal Id
# 0  78373RDFGT94949  2020-01-03   EFJSOJF984929389
# 1  78373RDFGT94930  2020-10-23  78373RDFGT9494fds

# %%
df_concat = pd.concat([df_new,add],ignore_index = True)
# Out:
# c:\users\aadhi\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df_concat.tail()
# Out:
#              Company Id                 Date               Date of Meal  \
# 14359  I27J9NPYES4BIXBR  2016-04-10 00:00:00  2016-04-10 07:00:00+02:00
# 14360  I27J9NPYES4BIXBR  2015-07-19 00:00:00  2015-07-21 09:00:00+02:00
# 14361               NaN                  NaT                        NaN
# 14362               NaN           2020-01-03                        NaN
# 14363               NaN           2020-10-23                        NaN
#
#       Heroes Adjustment            Meal Id                 Meal Price  \
# 14359             False   AV323CBF7N78MCYD                         81
# 14360             False   RDLHP30JLO9RYWDR                        210
# 14361               NaN                NaN  Not a number but a string
# 14362               NaN   EFJSOJF984929389                        NaN
# 14363               NaN  78373RDFGT9494fds                        NaN
#
#                Order Id                              Participants Type of Meal
# ...

# %%
df_concat = df_concat.reset_index(drop = True)

# %%
df_concat.tail()
# Out:
#              Company Id                 Date               Date of Meal  \
# 14359  I27J9NPYES4BIXBR  2016-04-10 00:00:00  2016-04-10 07:00:00+02:00
# 14360  I27J9NPYES4BIXBR  2015-07-19 00:00:00  2015-07-21 09:00:00+02:00
# 14361               NaN                  NaT                        NaN
# 14362               NaN           2020-01-03                        NaN
# 14363               NaN           2020-10-23                        NaN
#
#       Heroes Adjustment            Meal Id                 Meal Price  \
# 14359             False   AV323CBF7N78MCYD                         81
# 14360             False   RDLHP30JLO9RYWDR                        210
# 14361               NaN                NaN  Not a number but a string
# 14362               NaN   EFJSOJF984929389                        NaN
# 14363               NaN  78373RDFGT9494fds                        NaN
#
#                Order Id                              Participants Type of Meal
# ...

# %%
## Merge

# %%
order_data = pd.read_csv("order_leads.csv")
sales_data = pd.read_csv("sales_team.csv")

# %%
order_data.head()
# Out:
#            Order Id        Company Id            Company Name        Date  \
# 0  80EYLOKP9E762WKG  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2017-02-18
# 1  TLEXR1HZWTUTBHPB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2015-07-30
# 2  839FKFW2LLX4LMBB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2016-05-27
# 3  97OX39BGVMHODLJM  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2018-09-27
# 4  5T4LGH4XGBWOD49Z  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2016-01-14
#
#    Order Value  Converted
# 0       4875.0        1.0
# 1       8425.0        0.0
# 2       4837.0        0.0
# 3        343.0        0.0
# 4        983.0        0.0

# %%
sales_data.head()
# Out:
#            Sales Rep      Sales Rep Id                    Company Name  \
# 0  Jessie Mcallister  97UNNAT790E0WM4N          Chimera-Chasing Casbah
# 1  Jessie Mcallister  97UNNAT790E0WM4N                Tangential Sheds
# 2  Jessie Mcallister  97UNNAT790E0WM4N                   Two-Mile Grab
# 3  Jessie Mcallister  97UNNAT790E0WM4N  Three-Men-And-A-Helper Congo'S
# 4  Jessie Mcallister  97UNNAT790E0WM4N        Biophysical Battleground
#
#          Company Id
# 0  LJKS5NK6788CYMUU
# 1  36MFTZOYMTAJP1RK
# 2  H3JRC7XX7WJAD4ZO
# 3  HB25MDZR0MGCQUGX
# 4  7RVA8TIVBLBXMNO4

# %%
df.head()
# Out:
#            Order Id       Date           Meal Id        Company Id  \
# 0  839FKFW2LLX4LMBB 2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1  97OX39BGVMHODLJM 2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2  041ORQM5OIHTIU6L 2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3  YT796QI18WNGZ7ZJ 2014-04-12  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4  6YLROQT27B6HRF4E 2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
#
#                 Date of Meal                       Participants Meal Price  \
# 0  2016-05-31 07:00:00+02:00                   ['David Bishop']        469
# 1  2018-10-01 20:00:00+02:00                   ['David Bishop']         22
# 2  2014-08-23 14:00:00+02:00                 ['Karen Stansell']        314
# 3  2014-04-07 21:00:00+02:00                   ['Addie Patino']        438
# 4  2015-07-27 14:00:00+02:00  ['Addie Patino' 'Susan Guerrero']        690
#
#   Type of Meal Heroes Adjustment
# 0    breakfast             False
# 1       dinner             False
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.isna().sum()
# Out:
# Order Id             0
# Date                 0
# Meal Id              0
# Company Id           0
# Date of Meal         1
# Participants         1
# Meal Price           1
# Type of Meal         1
# Heroes Adjustment    1
# dtype: int64

# %%
df.shape
# Out:
# (14362, 9)

# %%
sales_data.columns
# Out:
# Index(['Sales Rep', 'Sales Rep Id', 'Company Name', 'Company Id'], dtype='object')

# %%
pd.merge(df,sales_data).shape
# Out:
# (14361, 12)

# %%
pd.merge(df,sales_data)
# Out:
#                Order Id        Date           Meal Id        Company Id  \
# 0      839FKFW2LLX4LMBB  2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1      97OX39BGVMHODLJM  2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2      041ORQM5OIHTIU6L  2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3      YT796QI18WNGZ7ZJ  2014-04-12  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4      6YLROQT27B6HRF4E  2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
# 5      AT0R4DFYYAFOC88Q  2014-07-21  W48JPR1UYWJ18NC6  LJKS5NK6788CYMUU
# 6      2DDN2LHS7G85GKPQ  2014-04-29  1MKLAKBOE3SP7YUL  LJKS5NK6788CYMUU
# 7      FM608JK1N01BPUQN  2014-05-08  E8WJZ1FOSKZD2MJN  36MFTZOYMTAJP1RK
# 8      CK331XXNIBQT81QL  2015-05-23  CTZSFFKQTY7SBZ4J  36MFTZOYMTAJP1RK
# 9      FESGKOQN2OZZWXY3  2016-01-10  US0NQYNNHS1SQJ4S  36MFTZOYMTAJP1RK
# 10     YITOTLOF0MWZ0VYX  2016-10-03  RGYX8772307H78ON  36MFTZOYMTAJP1RK
# 11     8RIGCF74GUEQHQEE  2018-07-23  5XK0KTFTD6OAP9ZP  36MFTZOYMTAJP1RK
# ...

# %%
pd.merge(df[['Order Id','Meal Id','Participants']]
        ,order_data.rename(columns = {"Order Id":"Alternate Id"}),
        left_on ='Order Id',
        right_on= 'Alternate Id')
# Out:
#                Order Id           Meal Id  \
# 0      839FKFW2LLX4LMBB  INBUX904GIHI8YBD
# 1      97OX39BGVMHODLJM  J0MMOOPP709DIDIE
# 2      041ORQM5OIHTIU6L  E4UJLQNCI16UX5CS
# 3      YT796QI18WNGZ7ZJ  C9SDFHF7553BE247
# 4      6YLROQT27B6HRF4E  48EQXS6IHYNZDDZ5
# 5      AT0R4DFYYAFOC88Q  W48JPR1UYWJ18NC6
# 6      2DDN2LHS7G85GKPQ  1MKLAKBOE3SP7YUL
# 7      FM608JK1N01BPUQN  E8WJZ1FOSKZD2MJN
# 8      CK331XXNIBQT81QL  CTZSFFKQTY7SBZ4J
# 9      FESGKOQN2OZZWXY3  US0NQYNNHS1SQJ4S
# 10     YITOTLOF0MWZ0VYX  RGYX8772307H78ON
# 11     8RIGCF74GUEQHQEE  5XK0KTFTD6OAP9ZP
# 12     TH60C9D8TPYS7DGG  KDSMP2VJ22HNEPYF
# 13     W1Y086SRAVUZU1AL  8IUOYVS031QPROUG
# 14     WKB58Q8BHLOFQAB5  E2K2TQUMENXSI9RP
# 15     N8DOG58MW238BHA9  KFR2TAYXZSVCHAA2
# 16     DPDV9UGF0SUCYTGW  6YV61SH7W9ECUZP0
# 17     KNF3E3QTOQ22J269  737T2U7604ABDFDF
# 18     LEED1HY47M8BR5VL  I22P10IQQD06MO45
# 19     LSJPNJQLDTIRNWAL  247IIVNN6CXGWINB
# 20     6UX5RMHJ1GK1F9YQ  LL4AOPXDM8V5KP5S
# ...

# %%
## Reshaping the Dataframes

# %%
df.head()
# Out:
#            Order Id       Date           Meal Id        Company Id  \
# 0  839FKFW2LLX4LMBB 2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1  97OX39BGVMHODLJM 2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2  041ORQM5OIHTIU6L 2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3  YT796QI18WNGZ7ZJ 2014-04-12  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4  6YLROQT27B6HRF4E 2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
#
#                 Date of Meal                       Participants Meal Price  \
# 0  2016-05-31 07:00:00+02:00                   ['David Bishop']        469
# 1  2018-10-01 20:00:00+02:00                   ['David Bishop']         22
# 2  2014-08-23 14:00:00+02:00                 ['Karen Stansell']        314
# 3  2014-04-07 21:00:00+02:00                   ['Addie Patino']        438
# 4  2015-07-27 14:00:00+02:00  ['Addie Patino' 'Susan Guerrero']        690
#
#   Type of Meal Heroes Adjustment
# 0    breakfast             False
# 1       dinner             False
# ...

# %%
import numpy as np
df = pd.read_csv("orders.csv")
df.groupby(['Type of Meal','Meal Id']).agg({"Meal Price":np.mean})

#Aggregation based on columns 
.agg({})

#Aggregation based on multiple 
.agg([])

#Single
.agg('min')
# Out:
#   File "<ipython-input-104-2fa910116d07>", line 6
#     .agg({})
#     ^
# SyntaxError: invalid syntax

# %%
temp = pd.pivot_table(df,index = ['Type of Meal','Meal Id','Heroes Adjustment'],values = 'Meal Price',aggfunc = np.mean,margins= True)

# %%
temp
# Out:
#                                                   Meal Price
# Type of Meal Meal Id          Heroes Adjustment
# Breakfast    001DCDCE6S200FA9 False                52.000000
#              003BA2DZAP6W2G2E False                75.000000
#              006R11Z6EG7B3P4E False               163.000000
#              00CWGA8NET6JVK8F False                18.000000
#              00IQ0SHRBHGD1PXN False               259.000000
#              00MV6B7HJU9MP6CU False               780.000000
#              00O2ML1603WO4PA5 False               266.000000
#              013AWRJJ35W8IL2A False               248.000000
#              022OB6HN7EJEZVIV False               828.000000
#              02F9FNTPKNLTHR7I False               235.000000
#              02LZRSN1HU1TYRHR False               630.000000
#              02P37V3BQRG0D6VH False               142.000000
#              03B3K59JTWYZ5P5I False               282.000000
#              03BO75GYZBAWOY34 False               602.000000
# ...

# %%
temp.unstack(level = 'Type of Meal')
# Out:
#                                     Meal Price
# Type of Meal                               All Breakfast Dinner  Lunch
# Meal Id          Heroes Adjustment
#                                     404.071443       NaN    NaN    NaN
# 001DCDCE6S200FA9 False                     NaN      52.0    NaN    NaN
# 003BA2DZAP6W2G2E False                     NaN      75.0    NaN    NaN
# 006R11Z6EG7B3P4E False                     NaN     163.0    NaN    NaN
# 00ATBBIP5WAHR9ED False                     NaN       NaN  460.0    NaN
# 00BZSMHAGSQMEMV8 False                     NaN       NaN    NaN  440.0
# 00CWGA8NET6JVK8F False                     NaN      18.0    NaN    NaN
# 00F6WJN9FTCEBXII False                     NaN       NaN    NaN  106.0
# 00IQ0SHRBHGD1PXN False                     NaN     259.0    NaN    NaN
# 00ISXEOJ0J0UTCM7 False                     NaN       NaN    NaN  244.0
# 00JS7BSRS8OX18YJ False                     NaN       NaN    NaN  150.0
# ...

# %%
#Home work: Read on 'Stack' 
#Home work: Work on 'Merge'

# %%
Type of Meal, Meal Id, Heros Adjustment- Agg of Meal Price
